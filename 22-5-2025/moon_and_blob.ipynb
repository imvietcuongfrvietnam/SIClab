# %%
from sklearn.datasets import make_blobs, make_moons
import matplotlib.pyplot as plt

# %%
X1, label1 = make_blobs(n_samples = 200, n_features = 2, centers = 2, cluster_std = 5, random_state=123)
plt.scatter(X1[:,0], X1[:,1], c=label1, alpha = 0.7)
plt.title('Dataset: #1: Original')
plt.show()

# %%
X2, label2 = make_moons(n_samples = 200, noise = 0.08, random_state=123)
plt.title('Dataset: #2: Original')
plt.scatter(X2[:,0], X2[:,1], c=label2, alpha = 0.7)
plt.show()

# %% [markdown]
# # Các trường hợp thử nghiệm #1:

# %% [markdown]
# ## Thay đổi sample:

# %%
X1, label1 = make_blobs(n_samples = 300, n_features = 2, centers = 2, cluster_std = 5, random_state=123)
plt.scatter(X1[:,0], X1[:,1], c=label1, alpha = 0.7)
plt.title('Dataset: #1: Original')
plt.show()

# %% [markdown]
# ## Thay đổi centers:

# %%
X1, label1 = make_blobs(n_samples = 200, n_features = 2, centers = 3, cluster_std = 5, random_state=123)
plt.scatter(X1[:,0], X1[:,1], c=label1, alpha = 0.7)
plt.title('Dataset: #1: Original')
plt.show()

# %% [markdown]
# ## Thay đổi cluster std:

# %%
X1, label1 = make_blobs(n_samples = 200, n_features = 2, centers = 2, cluster_std = 40, random_state=123)
plt.scatter(X1[:,0], X1[:,1], c=label1, alpha = 0.7)
plt.title('Dataset: #1: Original')
plt.show()

# %% [markdown]
# # Các trường hợp thử nghiệm #2:

# %% [markdown]
# ## Thay đổi noise:

# %%
X2, label2 = make_moons(n_samples = 200, noise = 0.16, random_state=123)
plt.title('Dataset: #2: Original')
plt.scatter(X2[:,0], X2[:,1], c=label2, alpha = 0.7)
plt.show()
